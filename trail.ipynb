# %%
# !git config --global user.name "JesusOfLagos"
# !git config --global user.email "jesuswrites20043@gmail.com"

# %%
token = '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'
username = 'JesusOfLagos'
repo = 'Trails'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'Trails'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (2/2), done.
# Receiving objects: 100% (8/8), done.
# remote: Total 8 (delta 0), reused 8 (delta 0), pack-reused 0 (from 0)

# %%
# %cd {repo}
# %ls
# Out:
# [Errno 2] No such file or directory: 'Trails'
# /content/Trails
# Tree/

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

dataset_path = '/content/Trails/datasets'

print(dataset_path)



def load_and_preprocess_images(dataset_path):
  images = []
  labels = []

  for trail_type in os.listdir(dataset_path):
    trail_type_path = os.path.join(dataset_path, trail_type)
    for image_filename in os.listdir(trail_type_path):
      image_path = os.path.join(trail_type_path, image_filename)
      image = cv2.imread(image_path)
      image = cv2.resize(image, (224, 224))
      image = image / 255.0
      images.append(image)
      labels.append(trail_type)
      print(trail_type)

  return np.array(images), np.array(labels)


images, labels = load_and_preprocess_images(dataset_path)

unique_labels = np.unique(labels)
label_mapping = {label: index for index, label in enumerate(unique_labels)}
numerical_labels = [label_mapping[label] for label in labels]


encoded_labels = to_categorical(numerical_labels)


X_train, X_test, y_train, y_test = train_test_split(
    images, encoded_labels, test_size=0.2, random_state=42
)
# Out:
# /content/Trails/datasets
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-19-1de3e9868133> in <cell line: 35>()
#      33
#      34
# ---> 35 images, labels = load_and_preprocess_images(dataset_path)
#      36
#      37 unique_labels = np.unique(labels)
#
# <ipython-input-19-1de3e9868133> in load_and_preprocess_images(dataset_path)
#      21   for trail_type in os.listdir(dataset_path):
#      22     trail_type_path = os.path.join(dataset_path, trail_type)
# ---> 23     for image_filename in os.listdir(trail_type_path):
#      24       image_path = os.path.join(trail_type_path, image_filename)
#      25       image = cv2.imread(image_path)
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/Trails/datasets/trail_data.csv'

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(len(unique_labels), activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d234be13ef54> in <cell line: 8>()
#       6 model.add(Flatten())
#       7 model.add(Dense(64, activation='relu'))
# ----> 8 model.add(Dense(len(unique_labels), activation='softmax'))
#
# NameError: name 'unique_labels' is not defined

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6f8ec71a7b2e> in <cell line: 1>()
# ----> 1 model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
#
# NameError: name 'X_train' is not defined

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e004a2549237> in <cell line: 1>()
# ----> 1 loss, accuracy = model.evaluate(X_test, y_test)
#       2 print('Test accuracy:', accuracy)
#       3
#
# NameError: name 'X_test' is not defined

# %%
model.save('trail_classification_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !git add .

# %%
# !git commit -m "base model"
# Out:
# [main 708cc0b] base model
#  4 files changed, 6 insertions(+), 1 deletion(-)
#  delete mode 100644 Tree/Branch/Auth-Service/Models/user.model.auth.ts
#  delete mode 100644 Tree/Branch/Auth-Service/app.ts
#  create mode 100644 datasets/trail_data.csv
#  create mode 100644 trail_classification_model.h5

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 41.59 MiB | 9.29 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/JesusOfLagos/Trails
#    5854b3b..708cc0b  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %cd /content
# Out:
# /content

# %%
# %ls
# Out:
# sample_data/  Trails/

# %%
# %cd /content/Trails
# Out:
# /content/Trails

# %%
# %ls
# Out:
# datasets/  trail_classification_model.h5

# %%
# !mv /content/Trails.ipynb /content/Trails
# Out:
# mv: cannot stat '/content/Trails.ipynb': No such file or directory

# %%
# %cd /content
# !find . -name "*.ipynb"
# Out:
# /content
